# %% [markdown]
# ## **Data Loading**

# %%
FILE_PATH_TSLA = "../data/processed/tsla_data_with_daily_return.csv"

## importing lib
import pandas as pd
import os
import numpy as np
import sys

# Add the src directory to the Python path
sys.path.append(os.path.abspath("../src"))

# %%
import pandas as pd
from model_training import *

df = pd.read_csv(FILE_PATH_TSLA, parse_dates=['Date'], index_col='Date')
tsla_price = df['Close']

train_df, test_df = split_time_series_data(data=df, split_date='2023-12-31')
# Out:
# Data split on: 2023-12-31
# Training set: 2015-07-08 to 2023-12-31 (3099 rows)
# Testing set:  2024-01-01 to 2025-07-30 (577 rows)

# %%
# training the model
import warnings
warnings.filterwarnings("ignore")

sys.path.append(os.path.abspath("../src"))
model, _ = train_auto_arima_model(train_df['Close'], is_seasonal=True, seasonal_period=5);
# Out:
# --- Starting SARIMA Model Training ---
# Finding optimal parameters with auto_arima...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[5] intercept   : AIC=17801.016, Time=4.38 sec
#  ARIMA(0,1,0)(0,0,0)[5] intercept   : AIC=17870.215, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[5] intercept   : AIC=17846.892, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,1)[5] intercept   : AIC=17850.201, Time=0.56 sec
#  ARIMA(0,1,0)(0,0,0)[5]             : AIC=17869.139, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,1)[5] intercept   : AIC=17800.620, Time=2.27 sec
#  ARIMA(2,1,2)(0,0,0)[5] intercept   : AIC=17813.190, Time=1.36 sec
#  ARIMA(2,1,2)(0,0,2)[5] intercept   : AIC=17801.137, Time=3.57 sec
#  ARIMA(2,1,2)(1,0,0)[5] intercept   : AIC=17799.954, Time=2.20 sec
#  ARIMA(2,1,2)(2,0,0)[5] intercept   : AIC=17801.065, Time=3.27 sec
#  ARIMA(2,1,2)(2,0,1)[5] intercept   : AIC=17803.053, Time=5.03 sec
#  ARIMA(1,1,2)(1,0,0)[5] intercept   : AIC=17835.301, Time=1.23 sec
#  ARIMA(2,1,1)(1,0,0)[5] intercept   : AIC=17832.363, Time=1.60 sec
#  ARIMA(3,1,2)(1,0,0)[5] intercept   : AIC=17791.266, Time=5.21 sec
#  ARIMA(3,1,2)(0,0,0)[5] intercept   : AIC=17795.684, Time=2.81 sec
#  ARIMA(3,1,2)(2,0,0)[5] intercept   : AIC=17791.966, Time=5.33 sec
#  ARIMA(3,1,2)(1,0,1)[5] intercept   : AIC=17794.316, Time=4.56 sec
#  ARIMA(3,1,2)(0,0,1)[5] intercept   : AIC=17791.555, Time=3.73 sec
#  ARIMA(3,1,2)(2,0,1)[5] intercept   : AIC=17793.971, Time=6.22 sec
#  ARIMA(3,1,1)(1,0,0)[5] intercept   : AIC=17837.283, Time=1.46 sec
#  ARIMA(4,1,2)(1,0,0)[5] intercept   : AIC=17793.206, Time=5.27 sec
#  ARIMA(3,1,3)(1,0,0)[5] intercept   : AIC=17801.090, Time=11.17 sec
#  ARIMA(2,1,3)(1,0,0)[5] intercept   : AIC=17791.785, Time=6.86 sec
#  ARIMA(4,1,1)(1,0,0)[5] intercept   : AIC=17839.075, Time=2.75 sec
#  ARIMA(4,1,3)(1,0,0)[5] intercept   : AIC=17783.401, Time=12.13 sec
#  ARIMA(4,1,3)(0,0,0)[5] intercept   : AIC=17781.529, Time=4.20 sec
#  ARIMA(4,1,3)(0,0,1)[5] intercept   : AIC=17783.494, Time=4.88 sec
#  ARIMA(4,1,3)(1,0,1)[5] intercept   : AIC=17785.940, Time=5.19 sec
#  ARIMA(3,1,3)(0,0,0)[5] intercept   : AIC=17815.883, Time=2.34 sec
#  ARIMA(4,1,2)(0,0,0)[5] intercept   : AIC=17797.444, Time=2.94 sec
#  ARIMA(4,1,4)(0,0,0)[5] intercept   : AIC=17759.976, Time=4.68 sec
#  ARIMA(4,1,4)(1,0,0)[5] intercept   : AIC=17761.287, Time=5.12 sec
#  ARIMA(4,1,4)(0,0,1)[5] intercept   : AIC=17761.390, Time=5.32 sec
#  ARIMA(4,1,4)(1,0,1)[5] intercept   : AIC=17762.098, Time=5.80 sec
#  ARIMA(3,1,4)(0,0,0)[5] intercept   : AIC=17775.601, Time=2.45 sec
#  ARIMA(4,1,4)(0,0,0)[5]             : AIC=17758.686, Time=2.30 sec
#  ARIMA(4,1,4)(1,0,0)[5]             : AIC=17759.920, Time=3.26 sec
#  ARIMA(4,1,4)(0,0,1)[5]             : AIC=17759.987, Time=4.02 sec
#  ARIMA(4,1,4)(1,0,1)[5]             : AIC=17760.872, Time=8.11 sec
#  ARIMA(3,1,4)(0,0,0)[5]             : AIC=17774.294, Time=2.45 sec
#  ARIMA(4,1,3)(0,0,0)[5]             : AIC=17780.651, Time=2.49 sec
#  ARIMA(3,1,3)(0,0,0)[5]             : AIC=17814.687, Time=1.67 sec
#
# Best model:  ARIMA(4,1,4)(0,0,0)[5]
# Total fit time: 160.999 seconds
#
# --- Best Model Found ---
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3099
# Model:               SARIMAX(4, 1, 4)   Log Likelihood               -8870.343
# Date:                Tue, 12 Aug 2025   AIC                          17758.686
# Time:                        15:19:31   BIC                          17813.033
# Sample:                    07-08-2015   HQIC                         17778.203
#                          - 12-31-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6906      0.034    -49.180      0.000      -1.758      -1.623
# ar.L2         -1.7200      0.057    -30.301      0.000      -1.831      -1.609
# ar.L3         -1.1851      0.060    -19.851      0.000      -1.302      -1.068
# ar.L4         -0.4650      0.039    -12.004      0.000      -0.541      -0.389
# ma.L1          1.7744      0.030     59.453      0.000       1.716       1.833
# ma.L2          1.9420      0.048     40.181      0.000       1.847       2.037
# ma.L3          1.4481      0.050     28.776      0.000       1.349       1.547
# ma.L4          0.6424      0.034     18.988      0.000       0.576       0.709
# sigma2        17.9662      0.154    116.359      0.000      17.664      18.269
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):             39537.16
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):             399.86   Skew:                            -1.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                        20.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Training final model with the best parameters...
# Model training complete.

# %%
from prediction_models import generate_forecast
# predictions = generate_forecast(fitted_model, n_periods, forecast_index, alpha=0.05)
predictions = generate_forecast(model, len(test_df), test_df.index, alpha=0.05)

import matplotlib.pyplot as plt
plt.figure(figsize=(14, 7))
plt.plot(test_df.index, test_df['Close'], label='Actual Prices', color='blue')
plt.plot(test_df.index, predictions, label='Predicted Prices', color='orange')
plt.title('TSLA Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# --- Generating Forecast for 577 periods ---
# Forecast generation complete.

# %%
# import ARIMA model
# import ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
model = ARIMA(train_df['Close'], order=(5, 1, 0))
fitted_model = model.fit()
# Generate predictions
n_periods = len(test_df)
forecast_index = test_df.index
predictions = fitted_model.forecast(steps=n_periods)
# Plot the results
plt.figure(figsize=(14, 7))
plt.plot(test_df.index, test_df['Close'], label='Actual Prices', color='blue')
plt.plot(test_df.index, predictions, label='Predicted Prices', color='orange')
plt.title('TSLA Stock Price Prediction using ARIMA')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
train_df["Close"].plot(label='Train Data', figsize=(14, 7))
test_df["Close"].plot(label='Test Data')
plt.title('TSLA Stock Price Train/Test Split')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
